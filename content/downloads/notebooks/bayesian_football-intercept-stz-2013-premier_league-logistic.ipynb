# %% [markdown]
# ## Sum to zero by subtracting mean, mu intercepts: season with greater spread

# %% [markdown]
# The paper is available [here](http://www.statistica.it/gianluca/Research/BaioBlangiardo.pdf).

# %%
# %matplotlib inline

# %%
import os
import math

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pymc

# %% [markdown]
# I got the data from [wikipedia](http://en.wikipedia.org/wiki/1991%E2%80%9392_Serie_A).  We'll start by loading

# %%
data_dir = os.path.join(os.getcwd(), 'data/')
data_file = data_dir + 'premier_league_13_14.txt'
df = pd.read_csv(data_file, sep='\t', index_col=0,)
df.head()
# Out:
#                 ARS  AST  CAR  CHE  CPA  EVE  FUL  HUL  LIV  MNC  MNU  NEW  \
# Home \ Away[1]
# Arsenal         NaN  1-3  2-0  0-0  2-0  1-1  2-0  2-0  2-0  1-1  0-0  3-0
# Aston Villa     1-2  NaN  2-0  1-0  0-1  0-2  1-2  3-1  0-1  3-2  0-3  1-2
# Cardiff City    0-3  0-0  NaN  1-2  0-3  0-0  3-1  0-4  3-6  3-2  2-2  1-2
# Chelsea         6-0  2-1  4-1  NaN  2-1  1-0  2-0  2-0  2-1  2-1  3-1  3-0
# Crystal Palace  0-2  1-0  2-0  1-0  NaN  0-0  1-4  1-0  3-3  0-2  0-2  0-3
#
#                 NOR  SOT  STO  SUN  SWA  TOT  WBA  WHU
# Home \ Away[1]
# Arsenal         4-1  2-0  3-1  4-1  2-2  1-0  1-0  3-1
# Aston Villa     4-1  0-0  1-4  0-0  1-1  0-2  4-3  0-2
# Cardiff City    2-1  0-3  1-1  2-2  1-0  0-1  1-0  0-2
# Chelsea         0-0  3-1  3-0  1-2  1-0  4-0  2-2  0-0
# Crystal Palace  1-1  0-1  1-0  3-1  0-2  0-1  3-1  1-0

# %% [markdown]
# Clearly, we need do some munging here.  Let's turn this into a long dataframe, and split the score into two numeric columns.

# %%
df.index = df.columns
rows = []
for i in df.index:
    for c in df.columns:
        if i == c: continue
        score = df.ix[i, c]
        score = [int(row) for row in score.split('-')]
        rows.append([i, c, score[0], score[1]])
df = pd.DataFrame(rows, columns = ['home', 'away', 'home_score', 'away_score'])
df.head()
# Out:
#   home away  home_score  away_score
# 0  ARS  AST           1           3
# 1  ARS  CAR           2           0
# 2  ARS  CHE           0           0
# 3  ARS  CPA           2           0
# 4  ARS  EVE           1           1

# %% [markdown]
# Much better, but still not done.  We need an easy way to refer to the teams.  Let's create a lookup table, which maps team name to a unique integer *i*.

# %%
teams = df.home.unique()
teams = pd.DataFrame(teams, columns=['team'])
teams['i'] = teams.index
teams.head()
# Out:
#   team  i
# 0  ARS  0
# 1  AST  1
# 2  CAR  2
# 3  CHE  3
# 4  CPA  4

# %% [markdown]
# Now, we can merge this into our main dataframe to create the columns i_home and i_away.

# %%
df = pd.merge(df, teams, left_on='home', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_home'}).drop('team', 1)
df = pd.merge(df, teams, left_on='away', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_away'}).drop('team', 1)
df.head()
# Out:
#   home away  home_score  away_score  i_home  i_away
# 0  ARS  AST           1           3       0       1
# 1  CAR  AST           0           0       2       1
# 2  CHE  AST           2           1       3       1
# 3  CPA  AST           1           0       4       1
# 4  EVE  AST           2           1       5       1

# %% [markdown]
# Now, let's extract the data into arrays, so that pymc can work with it:

# %%
observed_home_goals = df.home_score.values
observed_away_goals = df.away_score.values
home_team = df.i_home.values
away_team = df.i_away.values
num_teams = len(df.i_home.unique())
num_games = len(home_team)

# %%
g = df.groupby('i_away')
att_starting_points = np.log(g.away_score.mean())
g = df.groupby('i_home')
def_starting_points = -np.log(g.away_score.mean())

# %% [markdown]
# Now let's define the pymc model, mimicing the model used in the paper.

# %%
#hyper parameters
home = pymc.Normal('home', 0, .0001, value=0)
#tau_att = pymc.Gamma('tau_att', .1, .1, value=10)
#tau_def = pymc.Gamma('tau_def', .1, .1, value=10)
tau_att = pymc.Uniform('tau_att', 0, 100, value=10)
tau_def = pymc.Uniform('tau_def', 0, 100, value=10)
intercept = pymc.Normal('intercept', 0, .0001, value=0)

#team-specific parameters
atts_star = pymc.Logistic("atts_star", mu=0, tau=tau_att, size=num_teams, value=att_starting_points.values)
defs_star = pymc.Logistic("defs_star", mu=0, tau=tau_def, size=num_teams, value=def_starting_points.values) 

# trick to code the sum to zero contraint
@pymc.deterministic
def atts(atts_star=atts_star):
    atts = atts_star.copy()
    atts = atts - np.mean(atts_star)
    return atts

@pymc.deterministic
def defs(defs_star=defs_star):
    defs = defs_star.copy()
    defs = defs - np.mean(defs_star)
    return defs

@pymc.deterministic
def home_theta(home_team=home_team, away_team=away_team, home=home, 
               atts=atts, defs=defs, intercept=intercept): 
    return np.exp(intercept + home + atts[home_team] + defs[away_team])
  
@pymc.deterministic
def away_theta(home_team=home_team, away_team=away_team, home=home, 
               atts=atts, defs=defs, intercept=intercept): 
    return np.exp(intercept + atts[away_team] + defs[home_team])   


@pymc.potential
def constrain_tau(tau_att=tau_att, tau_def=tau_def):
    if tau_att > 100 or tau_def > 100:
        return -1e6
    return 0

home_goals = pymc.Poisson('home_goals', mu=home_theta, value=observed_home_goals, observed=True)
away_goals = pymc.Poisson('away_goals', mu=away_theta, value=observed_away_goals, observed=True)

mcmc = pymc.MCMC([home, intercept, tau_att, tau_def, 
                  home_theta, away_theta, atts_star, defs_star, atts, defs, home_goals, away_goals])
map_ = pymc.MAP( mcmc )
map_.fit()
mcmc.sample(200000, 10000, 8)
# Out:
#  [                  0%                  ] 1060 of 200000 complete in 0.5 sec
#  [                  1%                  ] 2140 of 200000 complete in 1.0 sec
#  [                  1%                  ] 3129 of 200000 complete in 1.5 sec
#  [                  2%                  ] 4171 of 200000 complete in 2.0 sec
#  [                  2%                  ] 5235 of 200000 complete in 2.5 sec
#  [-                 3%                  ] 6321 of 200000 complete in 3.0 sec
#  [-                 3%                  ] 7341 of 200000 complete in 3.5 sec
#  [-                 4%                  ] 8345 of 200000 complete in 4.0 sec
#  [-                 4%                  ] 9370 of 200000 complete in 4.5 sec
#  [-                 5%                  ] 10412 of 200000 complete in 5.0 sec
#  [--                5%                  ] 11453 of 200000 complete in 5.5 sec
#        -0.12584647,  0.18864525,  0.08882537, -0.06033691, -0.22393748])

# %%
atts_star.value
# Out:
# array([ 0.41663374, -0.24278131, -0.48957624,  0.37657162, -0.40464796,
#         0.26220781, -0.20234186, -0.08794026,  0.70918329,  0.60301457,
#         0.35025675, -0.01597423, -0.23973068,  0.24340276, -0.05824997,
#        -0.05335461,  0.26113711,  0.16131723,  0.01215494, -0.15144563])

# %%
defs_star.value
# Out:
# array([-0.24814432, -0.00424676,  0.25084226, -0.03641559,  0.01271446,
#        -0.09895416,  0.40515194, -0.09467061,  0.15056603, -0.21535858,
#        -0.02847693,  0.03169464,  0.18199595, -0.14206455,  0.06610168,
#         0.0579399 ,  0.0632783 ,  0.06851073,  0.05253986, -0.06089585])

# %%
defs.value
# Out:
# array([-0.26874974, -0.02485218,  0.23023684, -0.05702101, -0.00789096,
#        -0.11955958,  0.38454652, -0.11527603,  0.12996061, -0.235964  ,
#        -0.04908235,  0.01108922,  0.16139053, -0.16266997,  0.04549626,
#         0.03733448,  0.04267288,  0.04790531,  0.03193444, -0.08150127])

# %%
avg_att = atts.stats()['mean']
avg_def = defs.stats()['mean']
team_names = teams.team.values

fig, ax = plt.subplots()
ax.plot(avg_att, avg_def, 'o')
for label, x, y in zip(team_names, avg_att, avg_def):
    ax.annotate(label, xy=(x,y), xytext = (-5,5), textcoords = 'offset points')
ax.set_title('Attack vs Defense avg effect: 13-14 Premier League')
ax.set_xlabel('Avg attack effect')
ax.set_ylabel('Avg defense effect')

# %%
pymc.Matplot.plot(home)
# Out:
# Plotting home
# /Users/weitzenfeld/Envs/blog/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
pymc.Matplot.plot(tau_att)
# Out:
# Plotting tau_att

# %%
pymc.Matplot.plot(tau_def)
# Out:
# Plotting tau_def

# %%
pymc.Matplot.plot(intercept)
# Out:
# Plotting intercept

# %%
pymc.Matplot.plot(atts_star)
# Out:
# Plotting atts_star_0
# Plotting
#  atts_star_1
# Plotting
#  atts_star_2
# Plotting
#  atts_star_3
# Plotting
#  atts_star_4
# Plotting
#  atts_star_5
# Plotting
#  atts_star_6
# Plotting
#  atts_star_7
# Plotting
#  atts_star_8
# Plotting
#  atts_star_9
# Plotting
#  atts_star_10
# Plotting
#  atts_star_11
# Plotting
#  atts_star_12
# Plotting
#  atts_star_13
# Plotting
#  atts_star_14
# Plotting
#  atts_star_15
# Plotting
#  atts_star_16
# Plotting
#  atts_star_17
# Plotting
#  atts_star_18
# Plotting
#  atts_star_19

# %%
pymc.Matplot.plot(defs_star)
# Out:
# Plotting defs_star_0
# Plotting
#  defs_star_1
# Plotting
#  defs_star_2
# Plotting
#  defs_star_3
# Plotting
#  defs_star_4
# Plotting
#  defs_star_5
# Plotting
#  defs_star_6
# Plotting
#  defs_star_7
# Plotting
#  defs_star_8
# Plotting
#  defs_star_9
# Plotting
#  defs_star_10
# Plotting
#  defs_star_11
# Plotting
#  defs_star_12
# Plotting
#  defs_star_13
# Plotting
#  defs_star_14
# Plotting
#  defs_star_15
# Plotting
#  defs_star_16
# Plotting
#  defs_star_17
# Plotting
#  defs_star_18
# Plotting
#  defs_star_19

# %% [markdown]
# ### Simulate a season

# %%
def simulate_season():
    num_samples = atts.trace().shape[0]
    draw = np.random.randint(0, num_samples)
    atts_draw = pd.DataFrame({'att': atts.trace()[draw, :],})
    defs_draw = pd.DataFrame({'def': defs.trace()[draw, :],})
    home_draw = home.trace()[draw]
    intercept_draw = intercept.trace()[draw]
    season = df.copy()
    season = pd.merge(season, atts_draw, left_on='i_home', right_index=True)
    season = pd.merge(season, defs_draw, left_on='i_home', right_index=True)
    season = season.rename(columns = {'att': 'att_home', 'def': 'def_home'})
    season = pd.merge(season, atts_draw, left_on='i_away', right_index=True)
    season = pd.merge(season, defs_draw, left_on='i_away', right_index=True)
    season = season.rename(columns = {'att': 'att_away', 'def': 'def_away'})
    season['home'] = home_draw
    season['intercept'] = intercept_draw
    season['home_theta'] = season.apply(lambda x: math.exp(x['intercept'] + 
                                                           x['home'] + 
                                                           x['att_home'] + 
                                                           x['def_away']), axis=1)
    season['away_theta'] = season.apply(lambda x: math.exp(x['intercept'] + 
                                                           x['att_away'] + 
                                                           x['def_home']), axis=1)
    season['home_goals'] = season.apply(lambda x: np.random.poisson(x['home_theta']), axis=1)
    season['away_goals'] = season.apply(lambda x: np.random.poisson(x['away_theta']), axis=1)
    season['home_outcome'] = season.apply(lambda x: 'win' if x['home_goals'] > x['away_goals'] else 
                                                    'loss' if x['home_goals'] < x['away_goals'] else 'draw', axis=1)
    season['away_outcome'] = season.apply(lambda x: 'win' if x['home_goals'] < x['away_goals'] else 
                                                    'loss' if x['home_goals'] > x['away_goals'] else 'draw', axis=1)
    season = season.join(pd.get_dummies(season.home_outcome, prefix='home'))
    season = season.join(pd.get_dummies(season.away_outcome, prefix='away'))
    return season


def create_season_table(season):
    g = season.groupby('i_home')    
    home = pd.DataFrame({'home_goals': g.home_goals.sum(),
                         'home_goals_against': g.away_goals.sum(),
                         'home_wins': g.home_win.sum(),
                         'home_draws': g.home_draw.sum(),
                         'home_losses': g.home_loss.sum()
                         })
    g = season.groupby('i_away')    
    away = pd.DataFrame({'away_goals': g.away_goals.sum(),
                         'away_goals_against': g.home_goals.sum(),
                         'away_wins': g.away_win.sum(),
                         'away_draws': g.away_draw.sum(),
                         'away_losses': g.away_loss.sum()
                         })
    df = home.join(away)
    df['wins'] = df.home_wins + df.away_wins
    df['draws'] = df.home_draws + df.away_draws
    df['losses'] = df.home_losses + df.away_losses
    df['points'] = df.wins * 3 + df.draws
    df['gf'] = df.home_goals + df.away_goals
    df['ga'] = df.home_goals_against + df.away_goals_against
    df['gd'] = df.gf - df.ga
    df = pd.merge(teams, df, left_on='i', right_index=True)
    df = df.sort_index(by='points', ascending=False)
    return df  
    
def simulate_seasons(n=100):
    dfs = []
    for i in range(n):
        s = simulate_season()
        t = create_season_table(s)
        t['iteration'] = i
        dfs.append(t)
    return pd.concat(dfs, ignore_index=True)

# %%
df.head()
# Out:
#   home away  home_score  away_score  i_home  i_away
# 0  ARS  AST           1           3       0       1
# 1  CAR  AST           0           0       2       1
# 2  CHE  AST           2           1       3       1
# 3  CPA  AST           1           0       4       1
# 4  EVE  AST           2           1       5       1

# %%
season = simulate_season()
table = create_season_table(season)
good_cols = ['team', 'wins', 'draws', 'losses',  'gf', 'ga', 'gd', 'points']
table[good_cols]
# Out:
#    team  wins  draws  losses  gf  ga  gd  points
# 9   MNC    26      5       7  96  42  54      83
# 0   ARS    23      6       9  77  43  34      75
# 8   LIV    21      8       9  74  45  29      71
# 17  TOT    20      7      11  74  55  19      67
# 3   CHE    19      8      11  76  56  20      65
# 16  SWA    18      9      11  63  61   2      63
# 10  MNU    18      8      12  60  53   7      62
# 5   EVE    16     10      12  50  57  -7      58
# 11  NEW    14     11      13  52  50   2      53
# 19  WHU    14     10      14  45  54  -9      52
# 2   CAR    14      8      16  54  62  -8      50
# 18  WBA    14      8      16  47  49  -2      50
# 6   FUL    12      8      18  48  66 -18      44
# 1   AST    13      5      20  39  48  -9      44
# 13  SOT    10     11      17  44  58 -14      41
# 15  SUN     9     12      17  45  54  -9      39
# 7   HUL     9     11      18  35  50 -15      38
# 14  STO     9     10      19  39  58 -19      37
# 4   CPA    10      7      21  35  49 -14      37
# 12  NOR     5     10      23  23  66 -43      25

# %%
simuls = simulate_seasons(1000)

# %%
ax = simuls.points[simuls.team == 'MNC'].hist()
median = simuls.points[simuls.team == 'MNC'].median()
ax.set_title('Man City: 2013-14 points, 1000 simulations')
ax.plot([median, median], ax.get_ylim())
plt.annotate('Median: %s' % median, xy=(median + 1, ax.get_ylim()[1]-10))

# %%
ax = simuls.gf[simuls.team == 'MNC'].hist()
median = simuls.gf[simuls.team == 'MNC'].median()
ax.set_title('Man City: 2013-14 goals for, 1000 simulations')
ax.plot([median, median], ax.get_ylim())
plt.annotate('Median: %s' % median, xy=(median + 1, ax.get_ylim()[1]-10))

# %%
ax = simuls.points[simuls.team == 'CAR'].hist()
median = simuls.points[simuls.team == 'CAR'].median()
ax.set_title('Cardiff City: 2013-14 points, 1000 simulations')
ax.plot([median, median], ax.get_ylim())
plt.annotate('Median: %s' % median, xy=(median + 1, ax.get_ylim()[1]-10))

# %%
ax = simuls.gf[simuls.team == 'CAR'].hist()
median = simuls.gf[simuls.team == 'CAR'].median()
ax.set_title('Cardiff City: 2013-14 goals for, 1000 simulations')
ax.plot([median, median], ax.get_ylim())
plt.annotate('Median: %s' % median, xy=(median + 1, ax.get_ylim()[1]-10))

# %%
ax = simuls.ga[simuls.team == 'CAR'].hist()
median = simuls.ga[simuls.team == 'CAR'].median()
ax.set_title('Cardiff City: 2013-14 goals against, 1000 simulations')
ax.plot([median, median], ax.get_ylim())
plt.annotate('Median: %s' % median, xy=(median + 1, ax.get_ylim()[1]-10))

# %% [markdown]
# ## Create table demonstrating goals for and goals against falling within hdi

# %%
observed_season = data_dir + 'premier_league_13_14_table.csv'
observed_season = pd.read_csv(observed_season, index_col=0,)
observed_season.head()
# Out:
#       Pld   W  D  L   GF  GA  GD  Pts
# team
# MNC    38  27  5  6  102  37  65   86
# LIV    38  26  6  6  101  50  51   84
# CHE    38  25  7  6   71  27  44   82
# ARS    38  24  7  7   68  41  27   79
# EVE    38  21  9  8   61  39  22   72

# %%
simuls.head()
# Out:
#   team   i  home_draws  home_goals  home_goals_against  home_losses  \
# 0  MNC   9           3          51                   9            0
# 1  LIV   8           3          64                  19            1
# 2  ARS   0           4          39                  24            4
# 3  EVE   5           7          36                  16            2
# 4  SOT  13           6          30                  14            1
#
#    home_wins  away_draws  away_goals  away_goals_against  away_losses  \
# 0         16           5          46                  20            2
# 1         15           7          38                  26            5
# 2         11           4          34                  24            5
# 3         10           3          24                  25            7
# 4         12           3          22                  23            9
#
#    away_wins  wins  draws  losses  points   gf  ga  gd  iteration
# 0         12    28      8       2      92   97  29  68          0
# 1          7    22     10       6      76  102  45  57          0
# 2         10    21      8       9      71   73  48  25          0
# 3          9    19     10       9      67   60  41  19          0
# 4          7    19      9      10      66   52  37  15          0

# %%
g = simuls.groupby('team')
season_hdis = pd.DataFrame({'points_lower': g.points.quantile(.05),
                            'points_upper': g.points.quantile(.95),
                            'goals_for_lower': g.gf.quantile(.05),
                            'goals_for_upper': g.gf.quantile(.95),
                            'goals_against_lower': g.ga.quantile(.05),
                            'goals_against_upper': g.ga.quantile(.95),
                            })
season_hdis = season_hdis.join(observed_season)
column_order = ['points_lower', 'Pts', 'points_upper', 
                'goals_for_lower', 'GF', 'goals_for_upper',
                'goals_against_lower', 'GA', 'goals_against_upper',]
season_hdis = season_hdis[column_order]
season_hdis = season_hdis.sort_index(by='Pts', ascending=False)
season_hdis
# Out:
#       points_lower  Pts  points_upper  goals_for_lower   GF  goals_for_upper  \
# team
# MNC          67.00   86         95.00            77.00  102           121.00
# LIV          65.00   84         92.00            74.00  101           121.00
# CHE          48.00   82         78.05            49.00   71            87.00
# ARS          48.00   79         80.00            48.00   68            84.00
# EVE          44.00   72         73.00            44.00   61            78.00
# TOT          40.00   69         70.00            38.00   55            70.00
# MNU          46.00   64         77.00            45.00   64            79.05
# SOT          41.00   56         70.00            38.00   54            69.00
# STO          34.00   50         62.00            32.00   45            58.00
# NEW          32.00   49         61.05            31.00   43            60.00
# CPA          29.00   45         57.00            24.00   33            50.00
# SWA          39.00   42         69.00            38.00   54            70.00
# WHU          32.00   40         63.00            29.00   40            57.00
# AST          30.00   38         58.00            27.00   39            56.00
# SUN          32.00   38         61.00            30.00   41            59.00
# HUL          28.95   37         57.05            24.95   38            52.00
# WBA          36.00   36         62.00            35.00   43            60.00
# NOR          23.00   33         51.00            20.00   28            47.00
# FUL          24.00   32         54.00            29.00   40            57.00
# CAR          24.00   30         52.00            23.00   32            49.00
#
#       goals_against_lower  GA  goals_against_upper
# team
# MNC                 33.00  37                59.00
# LIV                 36.00  50                63.00
# CHE                 38.00  27                65.00
# ARS                 35.00  41                61.00
# EVE                 40.00  39                65.00
# TOT                 38.00  51                65.00
# MNU                 35.95  43                62.00
# SOT                 36.00  46                64.00
# STO                 40.00  52                65.00
# NEW                 41.00  59                69.00
# CPA                 38.00  48                65.00
# SWA                 39.00  54                67.00
# WHU                 39.00  51                66.00
# AST                 41.95  61                69.00
# SUN                 41.00  60                71.00
# HUL                 39.00  53                67.05
# WBA                 40.00  59                68.00
# NOR                 42.00  62                71.00
# FUL                 47.00  85                89.00
# CAR                 45.00  74                78.00
