# %% [markdown]
# ## No STZ, mu intercepts: season with greater spread; insisting on truncated normal bounds

# %% [markdown]
# The paper is available [here](http://www.statistica.it/gianluca/Research/BaioBlangiardo.pdf).

# %%
# %matplotlib inline

# %%
import os
import math

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pymc

# %% [markdown]
# I got the data from [wikipedia](http://en.wikipedia.org/wiki/1991%E2%80%9392_Serie_A).  We'll start by loading

# %%
data_dir = os.path.join(os.getcwd(), 'data/')
data_file = data_dir + 'seria_a_2013.txt'
df = pd.read_csv(data_file, sep='\t', index_col=0,)
df.head()
# Out:
#      ATA  BOL  CAG  CTN  CHV  FIO  GEN  INT  JUV  LAZ  LIV  MIL  NAP  PAR  \
# ATA  NaN  2-1  1-0  2-1  2-1  0-2  1-1  1-1  1-4  2-1  2-0  2-1  3-0  0-4
# BOL  0-2  NaN  1-0  1-2  0-0  0-3  1-0  1-1  0-2  0-0  1-0  3-3  2-2  1-1
# CAG  2-1  0-3  NaN  2-1  0-1  1-0  2-1  1-1  1-4  0-2  1-2  1-2  1-1  1-0
# CTN  2-1  2-0  1-1  NaN  2-0  0-3  1-1  0-3  0-1  3-1  3-3  1-3  2-4  0-0
# CHV  0-1  3-0  0-0  2-0  NaN  1-2  2-1  2-1  1-2  0-2  3-0  0-0  2-4  1-2
#
#      ROM  SAM  SAS  TOR  UDI  VER
# ATA  1-1  3-0  0-2  2-0  2-0  1-2
# BOL  0-1  2-2  0-0  1-2  0-2  1-4
# CAG  1-3  2-2  2-2  2-1  3-0  1-0
# CTN  4-1  2-1  0-0  1-2  1-0  0-0
# CHV  0-2  0-1  0-1  0-1  2-1  0-1

# %% [markdown]
# Clearly, we need do some munging here.  Let's turn this into a long dataframe, and split the score into two numeric columns.

# %%
rows = []
for i in df.index:
    for c in df.columns:
        if i == c: continue
        score = df.ix[i, c]
        score = [int(row) for row in score.split('-')]
        rows.append([i, c, score[0], score[1]])
df = pd.DataFrame(rows, columns = ['home', 'away', 'home_score', 'away_score'])
df.head()
# Out:
#   home away  home_score  away_score
# 0  ATA  BOL           2           1
# 1  ATA  CAG           1           0
# 2  ATA  CTN           2           1
# 3  ATA  CHV           2           1
# 4  ATA  FIO           0           2

# %% [markdown]
# Much better, but still not done.  We need an easy way to refer to the teams.  Let's create a lookup table, which maps team name to a unique integer *i*.

# %%
teams = df.home.unique()
teams = pd.DataFrame(teams, columns=['team'])
teams['i'] = teams.index
teams.head()
# Out:
#   team  i
# 0  ATA  0
# 1  BOL  1
# 2  CAG  2
# 3  CTN  3
# 4  CHV  4

# %% [markdown]
# Now, we can merge this into our main dataframe to create the columns i_home and i_away.

# %%
df = pd.merge(df, teams, left_on='home', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_home'}).drop('team', 1)
df = pd.merge(df, teams, left_on='away', right_on='team', how='left')
df = df.rename(columns = {'i': 'i_away'}).drop('team', 1)
df.head()
# Out:
#   home away  home_score  away_score  i_home  i_away
# 0  ATA  BOL           2           1       0       1
# 1  CAG  BOL           0           3       2       1
# 2  CTN  BOL           2           0       3       1
# 3  CHV  BOL           3           0       4       1
# 4  FIO  BOL           3           0       5       1

# %% [markdown]
# Now, let's extract the data into arrays, so that pymc can work with it:

# %%
#observed_scores = [(row['home_score'], row['away_score']) for i,row in df.iterrows()]
observed_home_goals = [row['home_score'] for i, row in df.iterrows()]
observed_away_goals = [row['away_score'] for i, row in df.iterrows()]
who_played_whom = [(row['i_home'], row['i_away']) for i,row in df.iterrows()]
num_teams = len(df.i_home.unique())
num_games = len(who_played_whom)

# %%
g = df.groupby('i_away')
att_starting_points = g.away_score.mean()
g = df.groupby('i_home')
def_starting_points = g.away_score.mean()

# %% [markdown]
# Now let's define the pymc model, mimicing the model used in the paper.

# %%
# 
NCT_DOF = 4

#hyper parameters
home = pymc.Normal('home', 0, .0001, value=0)
mu_att1 = pymc.TruncatedNormal('mu_att1', 0, .001, -3, 0, value=-.1)
mu_def1 = pymc.TruncatedNormal('mu_def1', 0, .001, 0, 3, value=.1)
mu_att3 = pymc.TruncatedNormal('mu_att3', 0, .001, 0, 3, value=.1)
mu_def3 = pymc.TruncatedNormal('mu_def3', 0, .001, -3, 0, value=-.1)
tau_att1 = pymc.Gamma('tau_att1', .01, .01, value=10)
tau_def1 = pymc.Gamma('tau_def1', .01, .01, value=10)
tau_att2 = pymc.Gamma('tau_att2', .01, .01, value=10)
tau_def2 = pymc.Gamma('tau_def2', .01, .01, value=10)
tau_att3 = pymc.Gamma('tau_att3', .01, .01, value=10)
tau_def3 = pymc.Gamma('tau_def3', .01, .01, value=10)
intercept = pymc.Normal('intercept', 0, .0001, value=0)

pi_att = pymc.Dirichlet("grp_att", theta=[1,1,1]) 
pi_def = pymc.Dirichlet("grp_def", theta=[1,1,1])

#team-specific parameters
group_att = pymc.Categorical('group_att', pi_att, size=num_teams)
group_def = pymc.Categorical('group_def', pi_def, size=num_teams)

@pymc.deterministic
def mu_atts(group_att=group_att, 
            mu_att1=mu_att1,
            mu_att3=mu_att3):
    mus_by_group = [mu_att1, 0, mu_att3]
    return [mus_by_group[i] for i in group_att]
    
@pymc.deterministic
def tau_atts(group_att=group_att, 
            tau_att1=tau_att1,
            tau_att2=tau_att2,
            tau_att3=tau_att3):
    taus_by_group = [tau_att1, tau_att2, tau_att3]
    return [taus_by_group[i] for i in group_att]

@pymc.deterministic
def mu_defs(group_def=group_def, 
            mu_def1=mu_def1,
            mu_def3=mu_def3):
    mus_by_group = [mu_def1, 0, mu_def3]
    return [mus_by_group[i] for i in group_def]

@pymc.deterministic
def tau_defs(group_def=group_def, 
            tau_def1=tau_def1,
            tau_def2=tau_def2,
            tau_def3=tau_def3):
    taus_by_group = [tau_def1, tau_def2, tau_def3]
    return [taus_by_group[i] for i in group_def]   

atts = np.empty(num_teams, dtype=object)
defs = np.empty(num_teams, dtype=object)

for i in range(num_teams):
    atts[i] = pymc.NoncentralT("att_%i" % i, mu=mu_atts[i], lam=tau_atts[i], nu=NCT_DOF)
    defs[i] = pymc.NoncentralT("def_%i" % i, mu=mu_defs[i], lam=tau_defs[i], nu=NCT_DOF)

@pymc.deterministic
def home_theta(who_played_whom=who_played_whom, home=home, 
               atts=atts, defs=defs, intercept=intercept): 
    home_attack = [atts[i[0]] for i in who_played_whom]
    away_defense = [defs[i[1]] for i in who_played_whom]
    return [math.exp(intercept + home + home_attack[i] + away_defense[i]) for i in range(num_games)]
    
@pymc.deterministic
def away_theta(who_played_whom=who_played_whom,
               atts=atts, defs=defs, intercept=intercept): 
    away_attack = [atts[i[1]] for i in who_played_whom]
    home_defense = [defs[i[0]] for i in who_played_whom]
    return [math.exp(intercept + away_attack[i] + home_defense[i]) for i in range(num_games)]

@pymc.potential 
def ensure_mus_within_bounds(mu_att1=mu_att1, mu_def1=mu_def1, mu_att3=mu_att3, mu_def3=mu_def3):
    """
    necessary because pymc doesn't respect bounds on truncated normal
    """
    if not -3 < mu_att1 < 0:
        return -1e6
    if not -3 < mu_def3 < 0:
        return -1e6
    if not 0 < mu_att3 < 3:
        return -1e6
    if not 0 < mu_def1 < 3:
        return -1e6
    return 0 
    
    
home_goals = pymc.Poisson('home_goals', mu=home_theta, value=observed_home_goals, observed=True)
away_goals = pymc.Poisson('away_goals', mu=away_theta, value=observed_away_goals, observed=True)

mcmc = pymc.MCMC([home, mu_att1, mu_att3, mu_def1, mu_def3, tau_att1, tau_att2, tau_att3, tau_def1, tau_def2, tau_def3,
                  mu_atts, tau_atts, mu_defs, tau_defs, atts, defs, intercept,
                  home_theta, away_theta, home_goals, away_goals])
#map_ = pymc.MAP( mcmc )
#map_.fit()
mcmc.sample(15000, 7500, 4)
# Out:
#  [                  0%                  ] 3 of 15000 complete in 0.9 sec
#  [                  0%                  ] 4 of 15000 complete in 1.4 sec
#  [                  0%                  ] 6 of 15000 complete in 2.3 sec
#  [                  0%                  ] 7 of 15000 complete in 2.8 sec
#  [                  0%                  ] 9 of 15000 complete in 3.8 sec
#  [                  0%                  ] 10 of 15000 complete in 4.3 sec
#  [                  0%                  ] 12 of 15000 complete in 5.3 sec
#  [                  0%                  ] 14 of 15000 complete in 6.4 sec
#  [                  0%                  ] 15 of 15000 complete in 7.0 sec
#  [                  0%                  ] 16 of 15000 complete in 7.6 sec
#  [                  0%                  ] 18 of 15000 complete in 8.5 sec
#  [                  0%                  ] 20 of 15000 complete in 9.3 sec
#  [                  0%                  ] 22 of 15000 complete in 10.1 sec
#  [                  0%                  ] 24 of 15000 complete in 11.1 sec
#  [                  0%                  ] 25 of 15000 complete in 11.6 sec
#  [                  0%                  ] 27 of 15000 complete in 12.5 sec
#  [                  0%                  ] 29 of 15000 complete in 13.4 sec
#  [                  0%                  ] 30 of 15000 complete in 14.0 sec
#  [                  0%                  ] 31 of 15000 complete in 14.7 sec
#  [                  0%                  ] 32 of 15000 complete in 15.2 sec
#  [                  0%                  ] 33 of 15000 complete in 15.7 sec
#  [                  0%                  ] 35 of 15000 complete in 16.5 sec
#  [                  0%                  ] 36 of 15000 complete in 17.1 sec
#  [                  0%                  ] 38 of 15000 complete in 18.0 sec
#  [                  0%                  ] 40 of 15000 complete in 19.0 sec
#  [                  0%                  ] 41 of 15000 complete in 19.6 sec
#  [                  0%                  ] 42 of 15000 complete in 20.2 sec
#  [-----------------99%----------------- ] 14956 of 15000 complete in 5570.7 sec
#  [-----------------99%----------------- ] 14958 of 15000 complete in 5571.4 sec
#  [-----------------99%----------------- ] 14960 of 15000 complete in 5572.1 sec
#  [-----------------99%----------------- ] 14962 of 15000 complete in 5572.8 sec
#  [-----------------99%----------------- ] 14964 of 15000 complete in 5573.4 sec
#  [-----------------99%----------------- ] 14966 of 15000 complete in 5574.1 sec
#  [-----------------99%----------------- ] 14968 of 15000 complete in 5574.8 sec
#  [-----------------99%----------------- ] 14970 of 15000 complete in 5575.5 sec
#  [-----------------99%----------------- ] 14972 of 15000 complete in 5576.2 sec
#  [-----------------99%----------------- ] 14974 of 15000 complete in 5577.0 sec
#  [-----------------99%----------------- ] 14976 of 15000 complete in 5577.7 sec
#  [-----------------99%----------------- ] 14978 of 15000 complete in 5578.4 sec
#  [-----------------99%----------------- ] 14980 of 15000 complete in 5579.1 sec
#  [-----------------99%----------------- ] 14982 of 15000 complete in 5579.9 sec
#  [-----------------99%----------------- ] 14984 of 15000 complete in 5580.6 sec
#  [-----------------99%----------------- ] 14986 of 15000 complete in 5581.3 sec
#  [-----------------99%----------------- ] 14988 of 15000 complete in 5582.1 sec
#  [-----------------99%----------------- ] 14990 of 15000 complete in 5582.8 sec
#  [-----------------99%----------------- ] 14992 of 15000 complete in 5583.5 sec
#  [-----------------99%----------------- ] 14994 of 15000 complete in 5584.1 sec
#  [-----------------99%----------------- ] 14996 of 15000 complete in 5584.9 sec
#  [-----------------99%----------------- ] 14998 of 15000 complete in 5585.5 sec
#  [-----------------100%-----------------] 15000 of 15000 complete in 5586.2 sec
#  [-----------------100%-----------------] 15000 of 15000 complete in 5586.6 sec

# %% [markdown]
# Let's see if we can recreate

# %%
atts_star[0].value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f6bfd91150a1> in <module>()
# ----> 1 atts_star[0].value
#
# NameError: name 'atts_star' is not defined

# %%
[float(i.value) for i in atts_star]

# %%
float(atts_star[0].value)

# %%
[i.value for i in atts_star]

# %%
defs.value

# %%
avg_att = [i.stats()['mean'] for i in atts]
avg_def = [i.stats()['mean'] for i in defs]
team_names = teams.team.values

fig, ax = plt.subplots()
ax.plot(avg_att, avg_def, 'o')
for label, x, y in zip(team_names, avg_att, avg_def):
    ax.annotate(label, xy=(x,y), xytext = (-5,5), textcoords = 'offset points')
ax.set_title('Attack vs Defense avg effect: 91-92 Serie A')
ax.set_xlabel('Avg attack effect')
ax.set_ylabel('Avg defense effect')

# %%
np.mean(atts.trace([:]))

# %%
pymc.Matplot.plot(home)

# %%
pymc.Matplot.plot(tau_att)

# %%
pymc.Matplot.plot(tau_def)

# %%
pymc.Matplot.plot(mu_att1)
# Out:
# Plotting mu_att1
# /Users/weitzenfeld/Envs/blog/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2499: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)

# %%
pymc.Matplot.plot(mu_att3)
# Out:
# Plotting mu_att3

# %%
pymc.Matplot.plot(intercept)
# Out:
# Plotting intercept

# %%
stophere

# %% [markdown]
# ### Simulate a season

# %%
def simulate_season():
    num_samples = atts.trace().shape[0]
    draw = np.random.randint(0, num_samples)
    atts_draw = pd.DataFrame({'att': atts.trace()[draw, :],})
    defs_draw = pd.DataFrame({'def': defs.trace()[draw, :],})
    home_draw = home.trace()[draw]
    intercept_draw = intercept.trace()[draw]
    season = df.copy()
    season = pd.merge(season, atts_draw, left_on='i_home', right_index=True)
    season = pd.merge(season, defs_draw, left_on='i_home', right_index=True)
    season = season.rename(columns = {'att': 'att_home', 'def': 'def_home'})
    season = pd.merge(season, atts_draw, left_on='i_away', right_index=True)
    season = pd.merge(season, defs_draw, left_on='i_away', right_index=True)
    season = season.rename(columns = {'att': 'att_away', 'def': 'def_away'})
    season['home'] = home_draw
    season['intercept'] = intercept_draw
    season['home_theta'] = season.apply(lambda x: math.exp(x['intercept'] + 
                                                           x['home'] + 
                                                           x['att_home'] + 
                                                           x['def_away']), axis=1)
    season['away_theta'] = season.apply(lambda x: math.exp(x['intercept'] + 
                                                           x['att_away'] + 
                                                           x['def_home']), axis=1)
    season['home_goals'] = season.apply(lambda x: np.random.poisson(x['home_theta']), axis=1)
    season['away_goals'] = season.apply(lambda x: np.random.poisson(x['away_theta']), axis=1)
    season['home_outcome'] = season.apply(lambda x: 'win' if x['home_goals'] > x['away_goals'] else 
                                                    'loss' if x['home_goals'] < x['away_goals'] else 'draw', axis=1)
    season['away_outcome'] = season.apply(lambda x: 'win' if x['home_goals'] < x['away_goals'] else 
                                                    'loss' if x['home_goals'] > x['away_goals'] else 'draw', axis=1)
    season = season.join(pd.get_dummies(season.home_outcome, prefix='home'))
    season = season.join(pd.get_dummies(season.away_outcome, prefix='away'))
    return season


def create_season_table(season):
    g = season.groupby('i_home')    
    home = pd.DataFrame({'home_goals': g.home_goals.sum(),
                         'home_goals_against': g.away_goals.sum(),
                         'home_wins': g.home_win.sum(),
                         'home_draws': g.home_draw.sum(),
                         'home_losses': g.home_loss.sum()
                         })
    g = season.groupby('i_away')    
    away = pd.DataFrame({'away_goals': g.away_goals.sum(),
                         'away_goals_against': g.home_goals.sum(),
                         'away_wins': g.away_win.sum(),
                         'away_draws': g.away_draw.sum(),
                         'away_losses': g.away_loss.sum()
                         })
    df = home.join(away)
    df['wins'] = df.home_wins + df.away_wins
    df['draws'] = df.home_draws + df.away_draws
    df['losses'] = df.home_losses + df.away_losses
    df['points'] = df.wins * 3 + df.draws
    df['gf'] = df.home_goals + df.away_goals
    df['ga'] = df.home_goals_against + df.away_goals_against
    df['gd'] = df.gf - df.ga
    df = pd.merge(teams, df, left_on='i', right_index=True)
    df = df.sort_index(by='points', ascending=False)
    return df  
    
def simulate_seasons(n=100):
    dfs = []
    for i in range(n):
        s = simulate_season()
        t = create_season_table(s)
        t['iteration'] = i
        dfs.append(t)
    return pd.concat(dfs, ignore_index=True)

# %%
df.head()

# %%
season = simulate_season()
table = create_season_table(season)
good_cols = ['team', 'wins', 'draws', 'losses',  'gf', 'ga', 'gd', 'points']
table[good_cols]

# %%
simuls = simulate_seasons(1000)

# %%
ax = simuls.points[simuls.team == 'JUV'].hist()
ax.set_title('Juventus: 2013-14 points, 1000 simulations')

# %%
ax = simuls.gf[simuls.team == 'JUV'].hist()
ax.set_title('Juventus: 2013-14 goals for, 1000 simulations')

# %%
ax = simuls.points[simuls.team == 'LIV'].hist()
ax.set_title('Livorno: 2013-14 points, 1000 simulations')
#plt.savefig()

# %%
ax = simuls.gf[simuls.team == 'LIV'].hist()
ax.set_title('Livorno: 2013-14 goals for, 1000 simulations')
#plt.savefig()

# %%
ax = simuls.ga[simuls.team == 'LIV'].hist()
ax.set_title('Livorno: 2013-14 goals against, 1000 simulations')

# %% [markdown]
# ## Create table demonstrating goals for and goals against falling within hdi

# %%
observed_season = data_dir + 'seria_a_2013_table.csv'
observed_season = pd.read_csv(observed_season, index_col=0,)
observed_season.head()

# %%
simuls.head()

# %%
g = simuls.groupby('team')
season_hdis = pd.DataFrame({'points_lower': g.points.quantile(.05),
                            'points_upper': g.points.quantile(.95),
                            'goals_for_lower': g.gf.quantile(.05),
                            'goals_for_upper': g.gf.quantile(.95),
                            'goals_against_lower': g.ga.quantile(.05),
                            'goals_against_upper': g.ga.quantile(.95),
                            })
season_hdis = season_hdis.join(observed_season)
column_order = ['points_lower', 'Pts', 'points_upper', 
                'goals_for_lower', 'GF', 'goals_for_upper',
                'goals_against_lower', 'GA', 'goals_against_upper',]
season_hdis = season_hdis[column_order]
season_hdis = season_hdis.sort_index(by='Pts', ascending=False)
season_hdis

# %%
foo = pd.DataFrame(atts_star.trace()[:, 0])
foo.head()

# %%
foo = pd.DataFrame(tau_att.trace())
foo.tail()

# %%
foo = pd.DataFrame(home_theta.trace())

# %%
foo[0].hist()

# %%
foo.head()

# %%
num_games

# %%
foo.hist()

# %%
STOP HERE.

# %% [markdown]
# More complicated model

# %%
# hyper parameters
home = pymc.Normal('home', 0, .0001, value=0)

# the bottom of the table
mu_1_att = pymc.TruncatedNormal('mu_1_att', 0, .001, a=-3, b=0)
mu_1_def = pymc.TruncatedNormal('mu_1_def', 0, .001, a=0, b=3)
# top of the table
mu_3_att = pymc.TruncatedNormal('mu_3_att', 0, .0001, a=0, b=3)
mu_3_def = pymc.TruncatedNormal('mu_3_def', 0, .0001, a=-3, b=0)
# middle
mu_2_att = pymc.Normal('mu_2_att', 0, .0001, value=0)
mu_2_def = pymc.Normal('mu_2_def', 0, .0001, value=0)

tau_1_att = pymc.Gamma('tau_1_att', .1, .1)
tau_1_def = pymc.Gamma('tau_1_def', .1, .1)
tau_2_att = pymc.Gamma('tau_2_att', .1, .1)
tau_2_def = pymc.Gamma('tau_2_def', .1, .1)
tau_3_att = pymc.Gamma('tau_3_att', .1, .1)
tau_3_def = pymc.Gamma('tau_3_def', .1, .1)


#team-specific latent variables
grp_att = pymc.Dirichlet("grp_att", theta=[1,1,1]) 
grp_def = pymc.Dirichlet("grp_def", theta=[1,1,1])

atts = pymc.Normal("atts", mu=grp_att, tau=tau_att, size=num_teams, value=np.zeros(num_teams))
defs = pymc.Normal("defs", mu=grp_def, tau=tau_def, size=num_teams, value=np.zeros(num_teams))
